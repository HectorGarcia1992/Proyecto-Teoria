# %%
import pandas as pd

# %%
df_clientes = pd.read_csv('Clientes.csv')

# %%
df_clientes
# Out:
#      ClienteID   Nombre     Apellido                          email  \
# 0            1      Ema       Espine                 eespine0@de.vu
# 1            2   Aileen      Cissell          acissell1@webnode.com
# 2            3   Joella     Miquelet           jmiquelet2@skype.com
# 3            4    Orton       Lavers              olavers3@about.me
# 4            5    Onida  Van Arsdale        ovanarsdale4@tripod.com
# ..         ...      ...          ...                            ...
# 995        996  Raynard         Noir         rnoirrn@craigslist.org
# 996        997    Keane       Dartan              kdartanro@nyu.edu
# 997        998   Renard      Cookson  rcooksonrp@simplemachines.org
# 998        999    Sayre    Danilenko     sdanilenkorq@canalblog.com
# 999       1000    Lotti     Pfeiffer            lpfeifferrr@icq.com
#
#     NúmeroIdentidad      Teléfono FechaNacimiento  TarjetaCredito
# 0       136691591-7  505-821-5536       7/23/1998    3.538210e+15
# ...

# %%
df_clientes= df_clientes.drop(columns=['ClienteID'])

# %%
df_clientes.to_csv('Clientes_modf.csv', index=False)

# %%
df_sucursales= pd.read_csv('Sucursales.csv')

# %%
df_sucursales
# Out:
#     SucursalID Nombre                 Dirección          Ciudad      Teléfono  \
# 0            1      O          773 Canary Drive     Tegucigalpa  596-342-3586
# 1            2      F        643 Blackbird Lane  San Pedro Sula  546-616-9970
# 2            3      I           78032 West Lane     Tegucigalpa  740-226-9201
# 3            4      I         251 Roxbury Drive     Tegucigalpa  283-553-1085
# 4            5      C        009 Carioca Circle     Tegucigalpa  627-978-6284
# 5            6      B      88 Florence Junction  San Pedro Sula  487-297-5769
# 6            7      F             3 Oxford Pass     Tegucigalpa  597-468-0969
# 7            8      E      50000 Bultman Center     Tegucigalpa  843-464-7195
# 8            9      A           5899 Lawn Court     Tegucigalpa  314-446-0599
# 9           10      L         4 Anzinger Center     Tegucigalpa  452-347-6488
# 10          11      A             58 Esker Hill     Tegucigalpa  250-675-6268
# ...

# %%
df_sucursales= df_sucursales.drop(columns=['SucursalID'])

# %%
df_sucursales.to_csv('sucursales_mod.csv', index= False)
